# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandrapraksh-prajapat/Regex/blob/main/Advance_Python/Pandas/pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# student_id  name ,course, total_fees , duration

# %%
import pandas as pd

data = {
    "student_id": [101,102,103,104,105,106,107,108,109,110],
    "name": ["Amit","Neha","Rahul","Priya","Karan","Sneha","Arjun","Pooja","Rohit","Anjali"],
    "course_name": ["BCA","BBA","MCA","MBA","B.Tech","B.Sc","M.Tech","B.Com","M.Sc","BA"],
    "total_fees": [60000,50000,70000,80000,90000,45000,85000,40000,65000,30000],
    "duration": ["3 years","3 years","2 years","2 years","4 years","3 years","2 years","3 years","2 years","3 years"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    student_id    name course_name  total_fees duration
# 0         101    Amit         BCA       60000  3 years
# 1         102    Neha         BBA       50000  3 years
# 2         103   Rahul         MCA       70000  2 years
# 3         104   Priya         MBA       80000  2 years
# 4         105   Karan      B.Tech       90000  4 years
# 5         106   Sneha        B.Sc       45000  3 years
# 6         107   Arjun      M.Tech       85000  2 years
# 7         108   Pooja       B.Com       40000  3 years
# 8         109   Rohit        M.Sc       65000  2 years
# 9         110  Anjali          BA       30000  3 years

# %%
# Export in csv file
df.to_csv("student_data.csv")

# %%
# Export in excel file
df.to_excel("student_data.xlsx")
